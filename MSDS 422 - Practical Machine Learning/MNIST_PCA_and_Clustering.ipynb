# %% [markdown]
# **Assignment 5: Principal Components Analysis & Clustering**
#
# **Group 3: Laura Fanelli, Mark Schieble, John Vaughan, Katie Zink**

# %% [markdown]
# (1) Begin by fitting a random forest classifier using the full set of 784 explanatory variables and the model training set (train.csv). Record the time it takes to fit the model and then evaluate the model on the test.csv data by submitting to Kaggle.com. Provide your Kaggle.com score and user ID.

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def print_image(df, first=0, last=3):
    for i in range(first,last):
        img = np.array(df.loc[i+100][1:]).reshape(28,28)
        label = df.loc[i+100][0]
        plt.imshow(img)
        plt.show()
        print('label',label)
print_image(df_train, 5, 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5f2f1f858c4a> in <module>()
#       9         plt.show()
#      10         print('label',label)
# ---> 11 print_image(df_train, 5, 6)
#
# <ipython-input-3-5f2f1f858c4a> in print_image(df, first, last)
#       4 def print_image(df, first=0, last=3):
#       5     for i in range(first,last):
# ----> 6         img = np.array(df.loc[i+100][1:]).reshape(28,28)
#       7         label = df.loc[i+100][0]
#       8         plt.imshow(img)
#
# ValueError: cannot reshape array of size 80 into shape (28,28)

# %%
X = df_train.iloc[:, 1:]
y = df_train['label']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=27)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RandomForestClassifier_ = RandomForestClassifier(n_jobs=-1, n_estimators=20)

# %%
RandomForestClassifier_.fit(X_train, y_train)
RandomForestClassifier_.score(X_test, y_test)

# %%
test_prediction = RandomForestClassifier_.predict(df_test)

# %%
df_prediction = list(zip(list(range(1, 28001)), test_prediction))

df_submission = pd.DataFrame(df_prediction, columns=['ImageId','Label'])
df_submission.to_csv('RandomForestClassifier_submission_.csv', index = False)

# %% [markdown]
# Kaggle Score = 0.95064
#
# Username: thatguy1020

# %% [markdown]
# (2) Execute principal components analysis (PCA) on the combined training and test set data together, generating principal components that represent 95 percent of the variability in the explanatory variables. The number of principal components in the solution should be substantially fewer than the 784 explanatory variables. Record the time it takes to identify the principal components.

# %% [markdown]
# **Link - to delete**
#
# This Link looks like it will be helpful: https://www.kaggle.com/ddmngml/pca-and-svm-on-mnist-dataset

# %%
df_train.head()

# %%
df_train.info()

# %%
df_test.info()

# %% [markdown]
# **end**
#
# I ran into troubles appending the datasets
